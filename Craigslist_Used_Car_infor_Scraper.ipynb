# %%
# start scraping information from just one page

from urllib.request import urlopen
from bs4 import BeautifulSoup

url='https://baltimore.craigslist.org/search/cta?s=0'

html = urlopen(url)
bs = BeautifulSoup(html.read(),'html.parser')
cars=bs.find_all('li',{ 'class':'result-row'})

scrapedCarsList=[]
for car in cars:
    salesTitle=car.find('a',{'class':'result-title hdrlnk'})
    price=car.find('span',{'class':'result-price'})
    postingDate=car.find('time',{'class':'result-date'})
    #Some listings do not have a price.
    if price!=None:
        new_car=[salesTitle.get_text(),postingDate.get_text(),price.get_text()]
        #print(new_car) #uncomment to see all the cars with a newline
        scrapedCarsList.append(new_car)
print(scrapedCarsList[0:3]) #uncomment to see the list of cars on the first page
len(scrapedCarsList)
# Out:
# [['02 Chevy Tahoe 4X4', 'Sep 14', '$2250'], ['2008 Nissan Rogue SL SUV AWD - Needs Transmission - $2,200 OBO', 'Sep 14', '$2200'], ['08 Saturn astra', 'Sep 14', '$1500']]
# 120

# %%
# now let's revise the code to write the results of the first page into a csv file named 'CarCraglist.csv'.

from urllib.request import urlopen
from bs4 import BeautifulSoup
import csv

with open('CarCraglist.csv', 'w',newline='') as myFile:
    writer = csv.writer(myFile)
    writer.writerow(["sales Title", "Listing Date", "Price"])

url='https://baltimore.craigslist.org/search/cta?s=0'
html = urlopen(url)
bs = BeautifulSoup(html.read(),'html.parser')
cars=bs.find_all('li',{ 'class':'result-row'})

scrapedCarsList=[]
for car in cars:
    salesTitle=car.find('a',{'class':'result-title hdrlnk'})
    price=car.find('span',{'class':'result-price'})
    postingDate=car.find('time',{'class':'result-date'})
    #Some listings do not have a price.
    if price!=None:
        new_car=[salesTitle.get_text(),postingDate.get_text(),price.get_text()]
        scrapedCarsList.append(new_car)

with open('CarCraglist.csv', 'a',newline='',encoding='utf-8') as myFile:
    writer = csv.writer(myFile)
    writer.writerows(scrapedCarsList)

# %%
#  create the list of URL's for the most recent 1,200 posting

baseURL='https://baltimore.craigslist.org/search/cta?s='
urlList=[]
for i in range(0,1201,120):
    newURL=baseURL+str(i)
    urlList.append(newURL)

print(urlList[0:50]) #uncomment to see the urls
len(urlList)
# Out:
# ['https://baltimore.craigslist.org/search/cta?s=0', 'https://baltimore.craigslist.org/search/cta?s=120', 'https://baltimore.craigslist.org/search/cta?s=240', 'https://baltimore.craigslist.org/search/cta?s=360', 'https://baltimore.craigslist.org/search/cta?s=480', 'https://baltimore.craigslist.org/search/cta?s=600', 'https://baltimore.craigslist.org/search/cta?s=720', 'https://baltimore.craigslist.org/search/cta?s=840', 'https://baltimore.craigslist.org/search/cta?s=960', 'https://baltimore.craigslist.org/search/cta?s=1080', 'https://baltimore.craigslist.org/search/cta?s=1200']
# 11

# %%
#  trun the scraping script into a function so that it can  takes the page number (0, 120, 240, ...) as input and returns a list of all the cars on the page in a list of lists format.

def craigslistCarsScrape(pageNumber):
    print('*** Scraping cars on page:',int(pageNumber/120+1),'***\n\n')

    baseURL='https://baltimore.craigslist.org/search/cta?s='
    url=baseURL+str(pageNumber)
    html = urlopen(url)
    bs = BeautifulSoup(html.read(),'html.parser')
    cars=bs.find_all('li',{ 'class':'result-row'})
    scrapedCarsList=[]            
    for car in cars:
        salesTitle=car.find('a',{'class':'result-title hdrlnk'})
        price=car.find('span',{'class':'result-price'})
        postingDate=car.find('time',{'class':'result-date'})
        #Some listings do not have a price.
        if price!=None:
            new_car=[salesTitle.get_text(),postingDate.get_text(),price.get_text()]
            scrapedCarsList.append(new_car)
    return scrapedCarsList

# %%
# error handling to make the codes more robust

from urllib.error import HTTPError
from urllib.error import URLError

def craigslistCarsScraper(pageNumber):
    print('*** Scraping cars on page:',int(pageNumber/120+1),'***\n\n')

    baseURL='https://baltimore.craigslist.org/search/cta?s='
    url=baseURL+str(pageNumber)
    
    try:
        
        html = urlopen(url)
    
    except HTTPError as e:
        print(e)
        print('-----------------------HTTPError----------------------')
        return None
    except URLError as e:
        print('Server cound not be found')
        print('-----------------------URLError----------------------')
        return None
    
    bs = BeautifulSoup(html.read(),'html.parser')
    
    try:
        
        cars=bs.find_all('li',{ 'class':'result-row'})
    
    except AttributeError as e:
        print('Tag was not found')
        print('-----------------------AttributeError----------------------')
    
    else:
        scrapedCarsList=[]
        for car in cars:
            salesTitle=car.find('a',{'class':'result-title hdrlnk'})
            price=car.find('span',{'class':'result-price'})
            postingDate=car.find('time',{'class':'result-date'})
            #Some listings do not have a price.
            if price!=None:
                new_car=[salesTitle.get_text(),postingDate.get_text(),price.get_text()]
                    
                scrapedCarsList.append(new_car)
               
        return scrapedCarsList

# %%
craigslistCarsScraper(600)
# Out:
# *** Scraping cars on page: 6 ***
# [['2004 Nissan Frontier x cab', 'Sep 12', '$5950'],
#  ['1995 Chevy 7500 Cat 3116 Diesel', 'Sep 12', '$5950'],
#  ['2008 Toyota Scion Tc- Nice!!', 'Sep 12', '$5000'],
#  ['2016 Jeep Cherokee 4x4 4WD SUV ACEPTAMOS TAX ID! SE HABLA ESPANOL!',
#   'Sep 12',
#   '$0'],
#  ['2005 grand cherokee as is', 'Sep 12', '$4000'],
#  ['Md state inspected 2010 Honda Accord EXL loaded $6800 obo',
#   'Sep 12',
#   '$6800'],
#  ['Chevrolet step side', 'Sep 12', '$16500'],
#  ['1989 Chevy Corvette', 'Sep 12', '$7200'],
#  ['2012 Kia Sorento. MD inspected', 'Sep 12', '$6900'],
#  ['2008 Dodge Grand Caravan SXT:  1 Owner, MD Insp, 84k mi',
#   'Sep 11',
#   '$8995'],
#  ['2004 Chevrolet Silverado Ext Cab 4WD:  MD Inspected, 143k mi',
#   'Sep 11',
#   '$11995'],
#  ['2008 GMC Yukon XL Denali AWD:  Local Trade, Like New, $13995',
#   'Sep 11',
#   '$13995'],
#  ['!!!! 2009 HYUNDAI SONATA 4DR 4CYL AUTO RUNS100% $3950 !!!',
#   'Sep 11',
#   '$3950'],
#  ['2008 Toyota Sienna', 'Sep 11', '$6000'],
#  ['2004 Nissan Maxima 85k miles and state inspected', 'Sep 11', '$5000'],
#  ['2011 HONDA CR-Z', 'Sep 11', '$3700'],
#  ['Very nice 2002 Ford Mustang (Rare 5spd with 6 cyl)', 'Sep 11', '$2500'],
#  ['Fully loaded 2005 Cadillac SRX SUV With Warrany (Pics Avail)',
#   'Sep 11',
#   '$3995'],
#  ['02 VW Passat 5speed 62k miles MD insp.', 'Sep 11', '$2950'],
#  ['Dodge SXT SUV Caliber 2007', 'Sep 11', '$2950'],
#  ['2014 Ford Focus Titanium Hatchback - $7200', 'Sep 11', '$7200'],
#  ['2008 dodge 1500', 'Sep 11', '$6000'],
#  ['2008 mercury grand marquis', 'Sep 11', '$3200'],
#  ['2017 Chevrolet Cruze Chevy BAD CREDIT DONT SWEAT IT! ✅', 'Sep 11', '$0'],
#  ['Hunday Accent 2007', 'Sep 11', '$1800'],
#  ['2008 Toyota Avalon', 'Sep 11', '$5500'],
#  ['2014 Ford F-150', 'Sep 11', '$28500'],
#  ['Beautiful 2007 Mercedes R350 4Matic (Low Miles)', 'Sep 11', '$7995'],
#  ['2015 Chevy suburban 1500 LT', 'Sep 11', '$22800'],
#  ['2008 Ford F-450 Super Duty XL 6.4L Powerstroke Bucket Truck',
#   'Sep 11',
#   '$17900'],
#  ['2008 International 7400 Crew Cab 110k Dump Plow Spreader Truck',
#   'Sep 11',
#   '$22900'],
#  ['2004 Chevrolet Express 3500 140k 12ft Utility Box Truck',
#   'Sep 11',
#   '$4950'],
#  ['1993 International 4700 DT466E 24ft Box Truck Side Door Pull out Ramp',
#   'Sep 11',
#   '$4900'],
#  ['2012 Chevrolet Express 3500 121k 16ft Box Truck', 'Sep 11', '$10900'],
#  ['2012 UD 2600 103k Tuned and Deleted 26 ft Box Truck Lift Gate',
#   'Sep 11',
#   '$24800'],
#  ['1996 CHEVY BLAZER LS 4x4 – 2 Door', 'Sep 11', '$2400'],
#  ['2011 Ford F-150 Crew Cab FX4 4X4 1-OWNER!!! LOCAL TRUCK!!!!',
#   'Sep 11',
#   '$22999'],
#  ['2008 Chevrolet Express 3500 136k 14ft Box Truck Pull Out Ramp',
#   'Sep 11',
#   '$7950'],
#  ['2007 International 7400 48k Crew Cab Dump Plow Spreader Truck',
#   'Sep 11',
#   '$25750'],
#  ['2000 International 4900 144k Manual 24 ft Box Truck Lift Gate',
#   'Sep 11',
#   '$7500'],
#  ['2012 INTERNATIONAL 4300 DUMP TRUCK. NEEDS SOME WORK. LOCATED IN VIRGIN',
#   'Sep 11',
#   '$7995'],
#  ['2015 Jeep Cherokee 4x4 4WD SUV ACEPTAMOS TAX ID! SE HABLA ESPANOL!',
#   'Sep 11',
#   '$0'],
#  ['2007 GMC C7500 Isuzu 7.8L Turbo Diesel 24 ft Box Truck', 'Sep 11', '$9500'],
#  ['2007 MACK 600 10.8L Diesel 26ft Box Truck', 'Sep 11', '$14700'],
#  ['1989 oldsmobile cutlass', 'Sep 11', '$1800'],
#  ['~PEARL WHITE~2011 LINCOLN MKX LIMITED EDITION~NAVI~LEATHER~4X4~CLEAN',
#   'Sep 11',
#   '$10995'],
#  ['2004 Sterling LT7500 Vactor 2110 Vacuum/Jetter Combo', 'Sep 11', '$67500'],
#  ['2009 Chevrolet Express 1500 8 Passenger Van', 'Sep 11', '$3900'],
#  ['2007 Nissan Sentra', 'Sep 11', '$1600'],
#  ['2004 chevy tahoe', 'Sep 11', '$400'],
#  ['2003 Audi A4 AWD Quattro 1.8T', 'Sep 11', '$2500'],
#  ['2009 GMC C7500 7.8L Isuzu Turbo Diesel Reefer Box Truck',
#   'Sep 11',
#   '$9600'],
#  ['2016 acura rdx', 'Sep 11', '$17995'],
#  ['2010 Ford F-450 CrewCab Lariat 4X4 DRW SOUTHERN TRUCK!!!! LOW MI',
#   'Sep 11',
#   '$34999'],
#  ['1999 International 4700 90k 26ft Box Truck MECHANIC SPECIAL',
#   'Sep 11',
#   '$3950'],
#  ['1998         chevy tahoe', 'Sep 11', '$400'],
#  ['2015 Dodge Ram 5500 CREW CAB ST FLAT BED DRW 4X4 1-OWNER!!!!!',
#   'Sep 11',
#   '$37999'],
#  ['2014 International 4300 Turbo Diesel 168k 22ft Box Truck Lift Gate',
#   'Sep 11',
#   '$21900'],
#  ['02’ Nissan Xterra 4x4/ Very Strong Machine/', 'Sep 11', '$2685'],
#  ['2004 ford explorer 2WD', 'Sep 11', '$500'],
#  ['*2009* *Toyota* *Camry* *LE 4dr Sedan 5A*', 'Sep 11', '$6507'],
#  ['1967 Ford Mustang Coupe:  Local Car in VERY Good Shape, Light Blue & Chr',
#   'Sep 11',
#   '$15995'],
#  ['2003 Mercury Grand Marquis GS:  62k mi, 1 Owner, Very Nice Car',
#   'Sep 11',
#   '$6995'],
#  ['2010 Subaru Forester 2.5X Premium', 'Sep 11', '$11995'],
#  ['2004 Jeep Grand Cherokee laredo', 'Sep 11', '$500'],
#  ['2006 Pontiac vibe', 'Sep 11', '$1600'],
#  ['2008 Range Rover Sport HSE', 'Sep 11', '$6900'],
#  ['05’ Cadillac Escalade ESV 145k Miles', 'Sep 11', '$3900'],
#  ['2006 Toyota Avalon', 'Sep 11', '$5900'],
#  ['Dodge Dakota SLT', 'Sep 11', '$2450'],
#  ['2010 TOYOTA COROLLA', 'Sep 11', '$6500'],
#  ['2016 Ford F-150 4x4 4WD F150 Truck BAD CREDIT DONT SWEAT IT! ✅',
#   'Sep 11',
#   '$0'],
#  ['*2007* *Cadillac* *Escalade ESV* *Base*', 'Sep 11', '$11988'],
#  ['*2000* *Lincoln* *Town Car* *Executive*', 'Sep 11', '$6988'],
#  ['2016 Lexus IS 300', 'Sep 11', '$23475'],
#  ['*2016* *Ford* *F-150* *CREW CAB PICKUP 4-DR*', 'Sep 11', '$23995'],
#  ['~AUTOBAHN EDITION~2011 VW GTI 2DRS~2.0 TURBO~6SPD MANUAL~SUNROOF~CLEAN',
#   'Sep 11',
#   '$7995'],
#  ['~MUST SEE~2006 JEEP COMMANDER LIMITED~HEMI~4X4~LEATHER~SUNROOF~3RD ROW',
#   'Sep 11',
#   '$6995'],
#  ['~MUST SEE~2008 JEEP COMMANDER LIMITED~HEMI~4X4~NAVI~TV~LTHR~3RD ROW~',
#   'Sep 11',
#   '$8995'],
#  ['~LOW MILES~2011 GMC CANYON CREW CAB 4DRS~4X4~PICK UP TRUCK~TOW PKG ~',
#   'Sep 11',
#   '$16995'],
#  ['~RUBICON~2011 JEEP WRANGLER 2DRS~6SPD MANUAL~4X4~ALLOYS~NO RUST~CLEAN',
#   'Sep 11',
#   '$13995'],
#  ['~NO RUST~2012 DODGE RAM 1500 LONG HORN EDITION~HEMI~CREW CAB~4X4~NAVI',
#   'Sep 11',
#   '$15995'],
#  ['~LOW MILES~2015 CHEVY SILVERADO 1500 CREW CAB~4X4~5.3L~PICK UP TRUCK~',
#   'Sep 11',
#   '$23995'],
#  ['~PEARL WHITE~2011 BUCIK ENCLAVE SUV~LUXURY~LEATHER~ALLOYS~VERY CLEAN~',
#   'Sep 11',
#   '$7995'],
#  ['~TRD ROCK WARRIOR~2011 TOYOTA TUNDRA CREW MAX~5.7L~4X4~NO RUST~TRUCK~',
#   'Sep 11',
#   '$18995'],
#  ['~TURBO~2008 CHEVY HHR SS~MANUAL~LEATHER~WHEELS~LOADED~CLEAN~',
#   'Sep 11',
#   '$4500'],
#  ['2006 Ford Five Hundred Limited', 'Sep 11', '$2000'],
#  ['2010 Hino 338 6 sp Cab and Chassis    Isuzu Mitsubishi Fuso  UD',
#   'Sep 11',
#   '$11785'],
#  ['GMC Envoy 2003', 'Sep 11', '$2300'],
#  ['1993 Ford Bronco', 'Sep 11', '$4500'],
#  ['2016 TOYOTA RAV4 LE - DOWN PAYMENT LOW AS $750!', 'Sep 11', '$0'],
#  ['2012 Subaru Forester', 'Sep 11', '$7000'],
#  ['2008 Ford Fusion - $3200', 'Sep 11', '$3200'],
#  ['2015 Honda Civic EX', 'Sep 11', '$8500'],
#  ['500 down bad credit approved', 'Sep 11', '$500'],
#  ['2010 Volkswagen CC Sport', 'Sep 11', '$5000'],
#  ['2008 Honda Accord Coupe', 'Sep 11', '$6500'],
#  ['2013 BMW 535GT ONLY 59K MILES IMMACULATE CONDITION FULLY LOADED',
#   'Sep 11',
#   '$15500'],
#  ['2015 Nissan Rogue Select', 'Sep 11', '$10900'],
#  ['2003 Mazda 6', 'Sep 11', '$900'],
#  ['2015 CHEVROLET CRUZE LT ORIGINAL 22K MILES LIKE NEW', 'Sep 11', '$8500'],
#  ['2006 CHRYSLER TOWN AND COUNTRY TOURING STOW N GO LOW MILES SUPER CLEAN',
#   'Sep 11',
#   '$4750'],
#  ['2017 SUBARU IMPREZA PREMIUM AWD ONLY 21K MILES', 'Sep 11', '$10500'],
#  ['2015 Hyundai Sonata  ACEPTAMOS TAX ID! SE HABLA ESPANOL!', 'Sep 11', '$0'],
#  ['2009 SUBARU OUTBACK 87K MILES FULLY SERVICED + INSPECTED',
#   'Sep 11',
#   '$8500'],
#  ['2008 Chevrolet HHR SS 4dr Wagon', 'Sep 11', '$0'],
#  ['2007 FORD F450 FLAT BED FBI OWNED BULLETPROOFED DIESEL',
#   'Sep 11',
#   '$19750'],
#  ['2011 FORD TRANSIT CONNECT ORIGINAL 23K MILES GOVERNMENT OWNED',
#   'Sep 11',
#   '$10850'],
#  ['2002 Dodge Durango Slt 4x4 wheel (101k miles', 'Sep 11', '$2500'],
#  ['2003 Chevrolet Express', 'Sep 11', '$3500'],
#  ['~low miles~2010 CHEVY CAMARO SS~AUTO~6.2L~LEATHER~ALLOYS~RUNS GREAT~',
#   'Sep 11',
#   '$13995'],
#  ['2000 Chevy Silverado 2500', 'Sep 11', '$2000'],
#  ['◆◆◆ ZERO DOWN - - - - - Bad Credit OK - - - - - HUGE SELECTION * * * *',
#   'Sep 11',
#   '$199'],
#  ['*2017* *Nissan* *Altima* *2.5 SV*', 'Sep 11', '$12999'],
#  ['*2001* *Lexus* *LS 430* **', 'Sep 11', '$6488'],
#  ['2019 Jeep Cherokee Limited', 'Sep 11', '$24975'],
#  ['Single Axle Day Cab For Sale in DE', 'Sep 11', '$15995'],
#  ['Jeep Wrangler RHD Right Hand Drive Postal Mail Jeeps Carrier 4x4 truck',
#   'Sep 11',
#   '$0'],
#  ['2014 Ford E-250  van Commercial', 'Sep 11', '$0'],
#  ['2008 Lexus RX 350 Base - SUV', 'Sep 11', '$10985']]

# %%
# run the function in a loop and write the resutls on a csv

with open('craigslist_cars_final.csv', 'w',newline='') as myFile:
    writer = csv.writer(myFile)
    writer.writerow(["Listing Title", "Listing Date", "Price"])

with open('craigslist_cars_final.csv', 'a',newline='',encoding='utf-8') as myFile:
    writer = csv.writer(myFile)
    for i in range(0,1201,120):
        scrapedCarsList=craigslistCarsScraper(i)
        writer.writerows(scrapedCarsList)

print('----------------------------------------Well done---------------------------------------------- ')
print('-----------------------------------Scraping completed------------------------------------------ ')
print('------------Please find the csv file in the folder where this scraping file exists------------- ')
# Out:
# *** Scraping cars on page: 1 ***
#
#
# *** Scraping cars on page: 2 ***
#
#
# *** Scraping cars on page: 3 ***
#
#
# *** Scraping cars on page: 4 ***
#
#
# *** Scraping cars on page: 5 ***
#
#
# *** Scraping cars on page: 6 ***
#
#
# *** Scraping cars on page: 7 ***
#
#
# *** Scraping cars on page: 8 ***
#
#
# *** Scraping cars on page: 9 ***
#
#
# *** Scraping cars on page: 10 ***
#
#
# *** Scraping cars on page: 11 ***
#
#
# ----------------------------------------Well done----------------------------------------------
# -----------------------------------Scraping completed------------------------------------------
# ------------Please find the csv file in the folder where this scraping file exists-------------
